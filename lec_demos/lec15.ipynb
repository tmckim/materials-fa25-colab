# %% [markdown]
# ## Before you start - Save this notebook!
#
# When you open a new Colab notebook from the WebCampus (like you hopefully did for this one), you cannot save changes. So it's  best to store the Colab notebook in your personal drive `"File > Save a copy in drive..."` **before** you do anything else.
#
# The file will open in a new tab in your web browser, and it is automatically named something like: "**Copy of lec15.ipynb**". You can rename this to just the title of the assignment "**lec15.ipynb**". Make sure you do keep an informative name (like the name of the assignment) so that you know which files to submit back to WebCampus for grading! More instructions on this are at the end of the notebook.
#
#
# **Where does the notebook get saved in Google Drive?**
#
# By default, the notebook will be copied to a folder called “Colab Notebooks” at the root (home directory) of your Google Drive. If you use this for other courses or personal code notebooks, I recommend creating a folder for this course and then moving the assignments AFTER you have completed them. <br>
#
# I also recommend you give the folder where you save your notebooks^ a different name than the folder we create below that will store the notebook resources you need each time you work through a course notebook. This includes any data files you will need, links to the images that appear in the notebook, and the files associated with the autograder for answer checking.<br>
# You should select a name other than '**NS499-DataSci-course-materials**'. <br>
# This folder gets overwritten with each assignment you work on in the course, so you should **NOT** store your notebooks in this folder that we use for course materials! <br><br>For example, you could create a folder called 'NS499-**notebooks**' or something along those lines.
# ___

# %% [markdown]
# For this lecture, we aren't going to pull in any data files, so there are no setup steps like usual.<br>
# We do still need to import packages below.

# %% [markdown]
# # Install & Import Packages

# %%
# Don't change this cell; Just run this cell
# If you restart colab, make sure to run this cell again after those above^
# install package needed

# %pip install datascience -q

# %%
# Import packages and other things needed
# Don't change this cell; Just run this cell
# If you restart colab, make sure to run this cell again after the first ones above^

from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %% [markdown]
# ## Learning Objectives ##

# %% [markdown]
# Topics:
# - `for` loops
# - review and simulate using `np.random.choice`
# - review and use `np.append`

# %% [markdown]
# # Iteration
# We want to repeat a process multiple times, and can use betting on one roll of a die as an example.
#
# Let's assume the following:
#
# - If the die shows 1 or 2 dots, my net gain is -1 dollar.
# - If the die shows 3 or 4 dots, my net gain is 0 dollars.
# - If the die shows 5 or 6 dots, my net gain is 1 dollar.
#
# The function `bet_on_one_roll` takes no argument. Each time it is called, it simulates one roll of a fair die and returns the net gain in dollars.

# %%
def bet_on_one_roll():
    """Returns my net gain on one bet"""
# finish function here

# %% [markdown]
# We can do this 1 time but running the function we just wrote above.

# %%
bet_on_one_roll()

# %% [markdown]
# We could run the cell repeatedly, but that's tedious. If we wanted to do it a thousand times or a million times, that's not how I want to spend my time!
#
# A more automated solution is to use a `for` statement to loop over the contents of a sequence - called *iteration*. <br>

# %% [markdown]
# To repeat a process `n` times, it is common to use the sequence `np.arange(n)` in the `for` statement. In our code we will use the name `i` to remind ourselves that it refers to an item.

# %%
# for statement goes here

# %% [markdown]
# We perform the same (random) action several times, so the code in the body of our `for` statement does not actually refer to `i`.

# %% [markdown]
# ## Augmenting Arrays
#
# The `for` statement above does simulate the results of five bets and prints the results.  However, we cannot use this information for further computation. So, we want to save what the results are from the `for` loop into an array.
# We can use a`for` statement to create an array of results and augment the array each time we go through the loop.
#
# The `append` method in `NumPy` helps us do this. The call `np.append(array_name, value)` evaluates to a new array that is `array_name` augmented by `value`. When you use `append`, keep in mind that all the entries of an array must have the same type.

# %% [markdown]
# But often while using `for` loops it will be convenient to change the array when augmenting it. We do this by assigning the augmented array to the same name as the original - essentially adding on our values from the loop each time.

# %% [markdown]
# ## Example: Betting on 5 Rolls
# We can now simulate five bets on the die and collect the results in an array that we will call the *collection array*. We will start out by creating an empty array for this, and then append the outcome of each bet. Notice that the body of the `for` loop contains two statements. Both statements are executed for each item in the given sequence.

# %%
# make an empty array

# for statement goes here
# inside the statement: call the function
# inside the statement: append the array

# name of the array so we can see the output

# %% [markdown]
# Let us rewrite the cell with the `for` statement unrolled. <br>
# Unrolling the loop is a helpful way to see what is happening, and illustrate our understanding based on concepts we have also previously learned in this course.<br>
# We are replicating what is happening in the loop, without actually using the `for` loop.

# %%
# unroll the loop

# make the empty array

# go through and write code to go through each item, run the function and append

# name of the array so we can see the output

# %% [markdown]
# The contents of the array are likely to be different from the array that we got by running the previous cell because of randomness in rolling the die. However, the process for creating the array is exactly the same.
#
# By storing the results in an array, we ca now use methods we have learned to do computations. For example, we can use `np.count_nonzero` to count the number of times money changed hands.

# %%
# count nonzero goes here

# %% [markdown]
# ## Example: Betting on 300 Rolls
# We can see the variation in the results of 300 bets by running exactly the same code for 300 bets instead of five.

# %%
# copy and paste our code from above, but increase the iterations to 300!

# %% [markdown]
# The array `outcomes` contains the results of all 300 bets.

# %%
# check the length of the array

# %% [markdown]
# To see how often the three different possible results appeared, we can use the array `outcomes` and `Table` methods to create a simple plot.

# %%
# make a table with our outcomes
# create a barh plot based on the count of each output option

# %% [markdown]
# Each of the three outcomes -1, 0, and 1 appeared approximately ~100 of the 300 times, so overall we see similar amounts for each on the plot.
